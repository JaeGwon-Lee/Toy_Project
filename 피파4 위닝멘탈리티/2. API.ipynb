# %%
import pandas as pd
import requests
import json

# %%
key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2NvdW50X2lkIjoiMTM1OTM5ODE4MyIsImF1dGhfaWQiOiIyIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIiwic2VydmljZV9pZCI6IjQzMDAxMTQ4MSIsIlgtQXBwLVJhdGUtTGltaXQiOiI1MDA6MTAiLCJuYmYiOjE2MjEwNjIwMDksImV4cCI6MTYzNjYxNDAwOSwiaWF0IjoxNjIxMDYyMDA5fQ.tOPOrUKq6s9Lt822StwTLaey98ATBCDcnVXp0z8yfEE'
header = {'Authorization' : key}
nickname = '피파하는콥'

# %% [markdown]
# #### user : 유저 닉네임으로 유저 정보 조회

# %%
url = f'https://api.nexon.co.kr/fifaonline4/v1.0/users?nickname={nickname}'
user = requests.get(url, headers=header).json()

# %%
accessid = user['accessId']
accessid
# Out:
# '5c2b3d413883651eece8f1da'

# %%
user['nickname']
# Out:
# '피파하는콥'

# %%
user['level']
# Out:
# 406

# %% [markdown]
# #### maxdivision : 유저 고유 식별자로 역대 최고 등급 조회

# %% [markdown]
# matchtype
# 30 : 리그 친선
# 40 : 클래식 1on1
# 50 : 공식경기
# 52 : 감독모드
# 60 : 공식 친선
# 204 : 볼타 친선
# 214 : 볼타 공식
# 224 : 볼타 AI대전
# 234 : 볼타 커스텀

# %% [markdown]
# division
# 800 : 슈퍼챔피언스
# 900 : 챔피언스
# 1000 : 슈퍼챌린지
# 1100 : 챌린지1
# 1200 : 챌린지2
# 1300 : 챌린지3
# 2000 : 월드클래스1
# 2100 : 월드클래스2
# 2200 : 월드클래스3
# 2300 : 프로1
# 2400 : 프로2
# 2500 : 프로3
# 2600 : 세미프로1
# 2700 : 세미프로2
# 2800 : 세미프로3
# 2900 : 유망주1
# 3000 : 유망주2
# 3100 : 유망주3

# %%
url = f'https://api.nexon.co.kr/fifaonline4/v1.0/users/{accessid}/maxdivision'
maxdivision = requests.get(url, headers=header).json()

# %%
maxdivision[0]['matchType']
# Out:
# 50

# %%
maxdivision[0]['division']
# Out:
# 2100

# %%
maxdivision[0]['achievementDate']
# Out:
# '2020-12-20T01:35:26'

# %%
maxdivision[1]['matchType']
# Out:
# 52

# %%
maxdivision[1]['division']
# Out:
# 2500

# %%
maxdivision[1]['achievementDate']
# Out:
# '2020-01-23T17:54:56'

# %% [markdown]
# #### matches : 유저 고유 식별자로 유저의 매치 기록 조회

# %%
matchtype = 50
offset = 0
limit = 100
url = f'https://api.nexon.co.kr/fifaonline4/v1.0/users/{accessid}/matches?matchtype={matchtype}&offset={offset}&limit={limit}'
matches = requests.get(url, headers=header).json()

# %%
matches
# Out:
# ['607433ec3881e665e2969827',
#  '607431232ec0ea4579f599a7',
#  '60742e6221be625c1750f37b',
#  '60742b60f642b70192fbecaf',
#  '607428dc3881e62d1a965190',
#  '607427994a74c7da982831ee',
#  '607424f240ac4c6e3500c579',
#  '6074221721be62316a50b0b5',
#  '60741efb264c1bb604ab3f71',
#  '60741c5266e0e583c93dbc44',
#  '607419be3881e6348395fb98',
#  '607416f29691a75f228c2af3',
#  '6074134db3c8540dec6e488d',
#  '60740ed12ec0ea6cf4f4e027',
#  '60740c095dd2d04d1ee83533',
#  '607405ccc0bf12a6167d472b',
#  '60740286b3c85425ab6dfbfa',
#  '6073ff05c4c4ca77ff09c405',
#  '6073fb38c4c4ca523109b314',
#  '6073f7a0b3c85422046dc980',
#  '6073f3d0264c1b6f0aaa5d4f',
#  '6073f0c56af99e2e985ce6a2',
#  '6073ef384a74c7e4b827276d',
#  '6073ec7366e0e5c4b13ce23a',
#  '6073e8f35dd2d042f6e7975f',
#  '6073e61121be62097d4fa899',
#  '6073e34b6af99ee4795caa88',
#  '6073e05b9691a7a03d8b2275',
#  '605ee3d9bea55aa32139e8d3',
#  '605ee0cabea55abaca39d15d',
#  '605ede1d1d54e321b7be8e59',
#  '605edb3f41207f0b7b17d4fc',
# ...

# %% [markdown]
# #### match : 매치 상세 기록 조회

# %% [markdown]
# position
# 0 : GK
# 1 : SW
# 2 : RWB
# 3 : RB
# 4 : RCB
# 5 : CB
# 6 : LCB
# 7 : LB
# 8 : LWB
# 9 : RDM
# 10 : CDM
# 11 : LDM
# 12 : RM
# 13 : RCM
# 14 : CM
# 15 : LCM
# 16 : LM
# 17 : RAM
# 18 : CAM
# 19 : LAM
# 20 : RF
# 21 : CF
# 22 : LF
# 23 : RW
# 24 : RS
# 25 : ST
# 26 : LS
# 27 : LW
# 28 : SUB

# %%
matchid = matches[0]
url = f'https://api.nexon.co.kr/fifaonline4/v1.0/matches/{matchid}'
match = requests.get(url, headers=header).json()

# %%
match
# Out:
# {'matchId': '607433ec3881e665e2969827',
#  'matchDate': '2021-04-12T21:00:39',
#  'matchType': 50,
#  'matchInfo': [{'accessId': '5c2b3d413883651eece8f1da',
#    'nickname': '피파하는콥',
#    'matchDetail': {'seasonId': 202104,
#     'matchResult': '승',
#     'matchEndType': 0,
#     'systemPause': 1,
#     'foul': 0,
#     'injury': 0,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 78,
#     'cornerKick': 0,
#     'possession': 52,
#     'offsideCount': 0,
#     'averageRating': 4.48889,
#     'controller': 'keyboard'},
#    'shoot': {'shootTotal': 3,
#     'effectiveShootTotal': 2,
#     'shootOutScore': 0,
#     'goalTotal': 2,
#     'goalTotalDisplay': 2,
#     'ownGoal': 0,
#     'shootHeading': 0,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 2,
#     'goalInPenalty': 1,
#     'shootOutPenalty': 0,
#     'goalOutPenalty': 0,
#     'shootPenaltyKick': 1,
#     'goalPenaltyKick': 1},
# ...

# %%
len(match)
# 딕셔너리 : matchId, matchDate, matchType, matchInfo
# Out:
# 4

# %%
match['matchDate']
# Out:
# '2021-04-12T21:00:39'

# %%
len(match['matchInfo'])
# 리스트 : 유저, 상대
# Out:
# 2

# %%
len(match['matchInfo'][0])
# 딕셔너리 : accessId, nickname, matchDetail, shoot, shootDetail, pass, defence, player
# Out:
# 8

# %%
match['matchInfo'][0]['matchDetail']
# Out:
# {'seasonId': 202104,
#  'matchResult': '승',
#  'matchEndType': 0,
#  'systemPause': 1,
#  'foul': 0,
#  'injury': 0,
#  'redCards': 0,
#  'yellowCards': 0,
#  'dribble': 78,
#  'cornerKick': 0,
#  'possession': 52,
#  'offsideCount': 0,
#  'averageRating': 4.48889,
#  'controller': 'keyboard'}

# %%
match['matchInfo'][0]['shoot']
# Out:
# {'shootTotal': 3,
#  'effectiveShootTotal': 2,
#  'shootOutScore': 0,
#  'goalTotal': 2,
#  'goalTotalDisplay': 2,
#  'ownGoal': 0,
#  'shootHeading': 0,
#  'goalHeading': 0,
#  'shootFreekick': 0,
#  'goalFreekick': 0,
#  'shootInPenalty': 2,
#  'goalInPenalty': 1,
#  'shootOutPenalty': 0,
#  'goalOutPenalty': 0,
#  'shootPenaltyKick': 1,
#  'goalPenaltyKick': 1}

# %%
match['matchInfo'][0]['shootDetail'][0]
# Out:
# {'goalTime': 1355,
#  'x': 0.91258430480957,
#  'y': 0.4892095923423767,
#  'type': 2,
#  'result': 1,
#  'spId': 241209331,
#  'spGrade': 1,
#  'spLevel': 5,
#  'spIdType': True,
#  'assist': False,
#  'assistSpId': -1,
#  'assistX': 0.5,
#  'assistY': 0.5,
#  'hitPost': False,
#  'inPenalty': True}

# %%
match['matchInfo'][0]['pass']
# Out:
# {'passTry': 95,
#  'passSuccess': 80,
#  'shortPassTry': 64,
#  'shortPassSuccess': 59,
#  'longPassTry': 5,
#  'longPassSuccess': 1,
#  'bouncingLobPassTry': 0,
#  'bouncingLobPassSuccess': 0,
#  'drivenGroundPassTry': 2,
#  'drivenGroundPassSuccess': 2,
#  'throughPassTry': 20,
#  'throughPassSuccess': 17,
#  'lobbedThroughPassTry': 1,
#  'lobbedThroughPassSuccess': 1}

# %%
match['matchInfo'][0]['defence']
# Out:
# {'blockTry': 10, 'blockSuccess': 0, 'tackleTry': 21, 'tackleSuccess': 13}

# %%
match['matchInfo'][0]['player'][0]
# Out:
# {'spId': 215181291,
#  'spPosition': 28,
#  'spGrade': 5,
#  'status': {'shoot': 0,
#   'effectiveShoot': 0,
#   'assist': 0,
#   'goal': 0,
#   'dribble': 0,
#   'intercept': 0,
#   'defending': 0,
#   'passTry': 0,
#   'passSuccess': 0,
#   'dribbleTry': 0,
#   'dribbleSuccess': 0,
#   'ballPossesionTry': 0,
#   'ballPossesionSuccess': 0,
#   'aerialTry': 0,
#   'aerialSuccess': 0,
#   'blockTry': 0,
#   'block': 0,
#   'tackleTry': 0,
#   'tackle': 0,
#   'yellowCards': 0,
#   'redCards': 0,
#   'spRating': 0}}
